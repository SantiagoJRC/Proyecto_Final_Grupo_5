# %%
from funciones import desviacion

# %%
CP1 = desviacion("Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv", 'CP1')
CP2 = desviacion("Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv", 'CP2')
CP3 = desviacion("Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv", 'CP3')
NF = desviacion("Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv", 'NF')

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 48.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 50.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 42.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 57.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [matplotlib]8 [matplotlib]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
import os
os.chdir("..")

# %%
import os
os.listdir()
# Out:
# ['.git',
#  'titanic',
#  'README.md',
#  'figuras',
#  '.gitignore',
#  '.devcontainer',
#  'pandas']

# %%
cat = ["CP1","CP2","CP3","NF"]
proms = [CP1, CP2, CP3, NF]

plt.bar(cat, proms)
plt.title("Desviaciones")
plt.ylabel("Desviacion")
plt.savefig("figuras/Desviaciones.png", dpi=300, bbox_inches="tight")
plt.show()
