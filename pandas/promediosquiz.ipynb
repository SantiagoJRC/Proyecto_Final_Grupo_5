# %%
from funciones import promedios

# %%
CP1 = promedios("Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv", 'CP1')
CP2 = promedios("Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv", 'CP2')
CP3 = promedios("Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv", 'CP3')
NF = promedios("Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv", 'NF')

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 49.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 68.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 41.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 54.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [matplotlib]8 [matplotlib]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
import os
os.chdir("..")

# %%
import os
os.listdir()
# Out:
# ['.git',
#  'titanic',
#  'README.md',
#  'figuras',
#  '.gitignore',
#  '.devcontainer',
#  'pandas']

# %%
cat = ["CP1","CP2","CP3","NF"]
proms = [CP1, CP2, CP3, NF]

plt.bar(cat, proms)
plt.title("Promedios")
plt.ylabel("Promedio")
plt.savefig("figuras/Promedios.png", dpi=300, bbox_inches="tight")
plt.show()
